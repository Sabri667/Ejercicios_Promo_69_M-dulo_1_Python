# %% [markdown]
# # Módulo 1 Variables: Nivel Inicial

# %%
#Crea la variable gatos que sea un número con el valor 8.
gatos=8
#Crea la variable perros que sea un texto con la palabra cuatro.
perros="cuatro"
#Imprime la variable gatos.
print(gatos)
#Imprime la variable perros.
print(perros)
#Imprime la variable perros seguida por la palabra más y la palabra perros otra vez.
print(perros + " más " + perros)
print(perros,"más perros")
# Out:
# 8
# cuatro
# cuatro más cuatro
# cuatro más perros

# %%
#Consigue que el ordenador devuelva el siguiente texto, usando las variable perros y gatos: cuatro más cuatro es igual a 8.
print( perros, "más",perros,"es igual a", gatos)
print(f"{perros} más {perros} es igual a {gatos}")
# Out:
# cuatro más cuatro es igual a 8
# cuatro más cuatro es igual a 8

# %%
#Consigue que el ordenador devuelva el siguiente texto, usando la variableperros: cuatro + cuatro = 8.
print(perros,"+",perros,"=",gatos)
print(f"{perros} + {perros} = {gatos}")
# Out:
# cuatro + cuatro = 8
# cuatro + cuatro = 8

# %%
#Define una variable `pizzas` con un valor `2` que sea del tipo float.
pizzas=float(2)
print(type(pizzas))
print(pizzas)
# Out:
# <class 'float'>
# 2.0

# %%
# Define `magdalenas` con un valor `2` que sea del tipo string.
magdalenas=str(2)
print(type(magdalenas))
print(magdalenas)
# Out:
# <class 'str'>
# 2

# %%
# Define `postres` con un valor `0` que sea del tipo int.
postres=int(0)
print(type(postres))
print(postres)
# Out:
# <class 'int'>
# 0

# %%
#Calcula la suma entre gatos y pizzas.
print(gatos + pizzas)
# Out:
# 10.0

# %%
#Calcula la diferencia entre gatos y pizzas.
print(gatos - pizzas)
# Out:
# 6.0

# %%
#Multiplica las cantidad de gatos por 2.
print(gatos * 2)

#Crea una variable piezas que sea 8 veces la cantidad de pizzas.
piezas=8*pizzas
print(piezas)
#Haz que la cantidad de piezas se aumente en 3.
piezas+=3
print(piezas)
#Calcula el cuadrado de 9 y guárdalo en una variable llamada superficie.
superficie=9**2
print(superficie)

#Divide superficie entre gatos para saber cuánta superficie le pertenece a cada uno.
superficie_gatos=superficie/gatos
#Ahora has lo mismo pero con las piezas.
piezas_gatos=superficie/piezas
#Ahora repite los ejercicios 20 y 21 pero redondeando el resultado a un sólo decimal usando round().
print(round(superficie_gatos,1))
print(round(piezas_gatos,1))
#¿Es verdad que hay más gatos que pizzas?
print(gatos > pizzas)
#¿Es verdad que hay menos gatos que superficie?
print(gatos < superficie)
#¿Es verdad que 2 veces la cantidad de pizzas es distinto de la cantidad de gatos?
print(piezas*2 != gatos)
#¿La variable piezas es mayor o igual a pizzas y superficie es distinto de cero?
print(piezas >= pizzas and superficie != 0)
#¿La variable piezas es mayor o igual a pizzas y menor que superficie?
print(piezas >= pizzas and piezas < superficie)
#Comprueba las comparaciones del ejercicio 27. en una sola línea, sin usar la variable piezas más que una sola vez.
print(superficie > piezas >= pizzas)
#Usa input() para preguntar a un usuario el día de su cumpleaños y guarda la respuesta en la variable dia_cumple.
dia_cumple=input("¿Qué día cumples años?")
#Usa input() para preguntar a un usuario el mes de su cumpleaños y guarda la respuesta en la variable mes_cumple.
mes_cumple=input("¿En qué mes cumples años?")
#Usa .strip() en ambas de las variables definidas.
dia_cumple=dia_cumple.strip()
mes_cumple=mes_cumple.strip().capitalize()
#Haz que fecha_cumple sea un string compuesto por el día y el mes.
fecha_cumple= dia_cumple + " de " +  mes_cumple + "."
fecha_cumple2= f"{dia_cumple} de {mes_cumple}."
#Imprime Fecha de cumpleaños es más el día y el mes.
print("Fecha de cumpleaños es " + fecha_cumple)
print("Fecha de cumpleaños es " + fecha_cumple2)
#Imprime la variable perros con todas las letras en mayúsculas.
print(perros.upper())
# Out:
# 16
# 16.0
# 19.0
# 81
# 10.1
# 4.3
# True
# True
# True
# True
# True
# True
# Fecha de cumpleaños es 2 de Enero.
# Fecha de cumpleaños es 2 de Enero.
# CUATRO

# %% [markdown]
# # Módulo 1 Variables: Nivel Intermedio

# %%
""" 1. Crea tres variables numéricas de tipo integer (entero), llamadas de la siguiente forma (elige los números que quieras):

numero1
numero2
numero3 Utilizando los operadores lógicos:
¿Es el numero1 mayor que el numero2?
¿Es el numero1 menor que el numero2 pero mayor que el numero3?
¿Es el numero3 igual que el numero2
¿Es el numero2 distinto que el numero1? """

numero1 = 12
numero2 = 2
numero3 = 4
print(numero1 > numero2)
print(numero1 < numero2 and numero1 > numero3)
print(numero3 == numero2)
print(numero2 != numero1)
# Out:
# True
# False
# False
# True

# %%
""" 2. Crea dos variables numéricas de tipo float (decimal) con dos decimales, llámalas de la siguiente forma:

altura1
altura2 Utilizando los operadores matemáticos aprendidos en la lección:
Cuál es la suma de las dos alturas
Cuál es la diferencia entre las alturas
Cuál es el resto de la división de las dos alturas
Cuál es resultado de la división de las dos alturas, redondead el resultado a un decimal."""

altura1 = float(1.64)
altura2 = float(1.57)
print(altura1 + altura2)
print(altura1 - altura2)
print(altura1 % altura2)
print(round(altura1/altura2, 1))
# Out:
# 3.21
# 0.06999999999999984
# 0.06999999999999984
# 1.0

# %%
""" 3. Escribe un programa usando la función input() que le pregunte al usuario su nombre y apellidos. Una vez que tengamos el nombre del usuario:

Imprime su nombre y apellidos todo en mayúsculas
Imprime su nombre y apellidos todo en minúsculas
Imprime su nombre y apellidos con la primera letra del nombre y los apellidos en mayúscula y el resto en minúscula.
Imprime solo la primera letra del nombre en mayúscula."""

nombre=input("¡Hola!, ¿Cuál es tu nombre y apellidos?")
print(nombre.upper())
print(nombre.lower())
print(nombre.title())
print(nombre.capitalize())
# Out:
# SABRINA GISELLE GOMEZ TRUJILLO
# sabrina giselle gomez trujillo
# Sabrina Giselle Gomez Trujillo
# Sabrina giselle gomez trujillo

# %%
""" 4.Escribe un programa usando la función input() que:

Le pregunte al usuario por una frase, almacenad este resultado en una variable.
Le pregunte al usuario por una vocal, almacenad este resultado en una variable.
Imprime la misma frase pero con la vocal introducida en mayúsculas. Pista: puedes usar el método .replace() para reemplazar la vocal por su versión en mayúscula."""
frase=input("Comparte una frase").lower()
vocal=input("¿Elige una vocal?").lower()
print(vocal)
if vocal in frase:
    print(frase[0].upper() + frase[1:].replace(vocal, vocal.upper()))
else:
    print(frase.capitalize())
# Out:
# a
# LA vidA es bellA!

# %%
""" 6. Crea un programa que realice los siguientes pasos:

Solicite al usuario que introduzca su lista de la compra en una sola línea, separando cada elemento por comas.
Ejemplo de entrada: leche, pan, huevos, fruta.

Convierte la entrada del usuario en una lista donde cada elemento sea un ítem de la compra.
Muestra cada ítem de la lista en una nueva línea."""

lista_de_compras=[item.strip() for item in input("Introduce tu lista de la compra, separando cada elemento por comas").split(",")]
#print(lista_de_compras)
#print(len(lista_de_compras))
print("\n".join(lista_de_compras))

print(*lista_de_compras, sep="\n")
# Out:
# uva
# manzana
# naranja
# pera
# uva
# manzana
# naranja
# pera
