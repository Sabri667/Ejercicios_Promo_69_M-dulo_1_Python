# %% [markdown]
# # Módulo 1 Listas: Nivel Inicial

# %%
#Haz una lista llamada colores donde almacenemos los primeros 6 colores que te vengan a la mente.
colores = ["verde","azul","amarillo","blanco","violeta","naranja"]

#Haz una lista llamada buses de las líneas de autobuses que pasan por tu casa.
buses = ["linea 1","linea 2","linea 3","linea 4","linea 5"]

#Apunta la previsión de temperaturas máximas para todos los días de esta semana en una lista llamada temperaturas.
temperaturas = [20, 22, 19, 25, 21, 18, 24]   
#Convierte tu nombre a una lista nombres de caracteres.
lista_nombre = list("Sabrina Giselle")
print(lista_nombre)
#Convierte tu primer apellido a una lista apellido de caracteres.
lista_apellido = list("GOMEZ TRUJILLO")
print(lista_apellido)
# Out:
# ['S', 'a', 'b', 'r', 'i', 'n', 'a', ' ', 'G', 'i', 's', 'e', 'l', 'l', 'e']
# ['G', 'O', 'M', 'E', 'Z', ' ', 'T', 'R', 'U', 'J', 'I', 'L', 'L', 'O']

# %%
#Cuántos búses pasan por tu casa?
print(len(buses))
#¿Cuántos caracteres hay en tu apellido(s) (inluyendo los espacios)?
print(len(lista_apellido))
#¿Cuáles son las temperaturas máximas (t_max) y mínimas (t_min) para esta semana?
t_max=(max(temperaturas))
t_min=(min(temperaturas))
print(f"temperatura máxima: {t_max} y temperatura mínima: {t_min}")
#Hay una 'e' en tu nombre?
print('e' in lista_nombre)
#Tienes el color 'rosa' en la lista de colores?
print('rosa' in colores)
#¿Tiene una 'x' tu nombre? (Usa not in)
print('x' not in lista_nombre)
#Haz una copia de temperaturas en dos nuevas listas: temperaturas2, y temperaturas3.
temperaturas2 = temperaturas.copy()
temperaturas3 = temperaturas.copy()
print(temperaturas2)
print(temperaturas3)
# Out:
# 5
# 14
# temperatura máxima: 25 y temperatura mínima: 18
# False
# False
# True
# [20, 22, 19, 25, 21, 18, 24]
# [20, 22, 19, 25, 21, 18, 24]

# %%
#Vacía el contenido de la variable temperaturas2
from locale import strxfrm


temperaturas2.clear()
print(temperaturas2)
#Imprime el contenido de temperaturas y temperaturas2.
print(temperaturas)
print(temperaturas2)
#Copia el contenido de nombres a nombres2.
nombres2=lista_nombre.copy()
print(nombres2)
#Copia el contenido de apellidos a apellidos2.
apellidos2=lista_apellido.copy()
print(apellidos2)
#Ordena la variable temperaturas3 de mayor a menor.
temperaturas3.sort(reverse=True)
print(temperaturas3)
#Ordena los caracteres de tu nombre y tu apellido en las listas nombres2 y apellidos2. Imprime el resultado y investiga: ¿qué orden ha cogido? ¿Cómo trata las mayúsculas?
lista_apellido.sort()
print(lista_apellido)
lista_nombre.sort()
print(lista_nombre)
lista_nombre_ordenada = sorted(lista_nombre, key=strxfrm) #o casefold para ignorar mayúsculas- no incluye acentos
print(lista_nombre_ordenada)

#¿Cuántas 'a' tiene tu nombre? ¿Y cuántas 'o'?
count_a_nombres=lista_nombre.count('a')
count_o_nombres=lista_nombre.count('o')
print(f"El número de 'a' en mi nombre es: {count_a_nombres} y el número de 'o' en mi nombre es: {count_o_nombres}")
#Verifica si los resultados de ejercicio 19 son iguales para la lista nombres2.
count_a_nombres2=nombres2.count('a')
count_o_nombres2=nombres2.count('o')
print(f"El número de 'a' en mi nombre es: {count_a_nombres2} y el número de 'o' en mi nombre es: {count_o_nombres2}")
# Out:
# []
# [20, 22, 19, 25, 21, 18, 24]
# []
# [' ', 'G', 'S', 'a', 'a', 'b', 'e', 'e', 'i', 'i', 'l', 'l', 'n', 'r', 's']
# [' ', 'E', 'G', 'I', 'J', 'L', 'L', 'M', 'O', 'O', 'R', 'T', 'U', 'Z']
# [25, 24, 22, 21, 20, 19, 18]
# [' ', 'E', 'G', 'I', 'J', 'L', 'L', 'M', 'O', 'O', 'R', 'T', 'U', 'Z']
# [' ', 'G', 'S', 'a', 'a', 'b', 'e', 'e', 'i', 'i', 'l', 'l', 'n', 'r', 's']
# [' ', 'G', 'S', 'a', 'a', 'b', 'e', 'e', 'i', 'i', 'l', 'l', 'n', 'r', 's']
# El número de 'a' en mi nombre es: 2 y el número de 'o' en mi nombre es: 0
# El número de 'a' en mi nombre es: 2 y el número de 'o' en mi nombre es: 0

# %%
#¿Cuántas veces esta semana llega la temperatura a la t_max? ¿Y cuántas a la t_min?
count_t_max=temperaturas.count(t_max)
count_t_min=temperaturas.count(t_min)
print(f"Esta semana la temperatura llega a la t_max {count_t_max} veces y a la t_min {count_t_min} veces")    

#Crea una lista llamada lista dias_en que contenga los elementos 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', y 'sunday'
lista_dias = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']
#Define temperaturas_diciembre 👇🏽:

temperaturas_diciembre = [10, 10, 13, 14, 12, 15,12, 11, 13, 17, 18, 15,15, 17, 17, 13, 13, 11,12, 10, 12, 14, 12, 12,11, 12, 16, 16, 14, 17, 18]

#¿Cuál es el penúltimo día de la semana?
print(lista_dias[-2])    

#¿Cuál es el último elemento de la lista de temperaturas de diciembre?
print(temperaturas_diciembre[-1])

#¿Está 'friday' en la lista de días en inglés? Si está, ¿dónde?
print("friday" in lista_dias)
lista_dias.index("friday")  
#¿Cuál era la temperatura máxima en diciembre?
print(max(temperaturas_diciembre))
#Encuentra el índice de 'miércoles' en dias_es.
lista_dias.index("wednesday")
#(Bonus) Imprime esta frase en pantalla: 'La temperatura máxima esta semana será 14 ºC, que ocurrirá en 1 días(s). El día más frío tendrá una temperatura máxima de 10 ºC, que ocurrirá en 2 día(s).'
print(f"La temperatura máxima esta semana será {t_max} ºC, que ocurrirá en {temperaturas.index(t_max)+1} días(s). El día más frío tendrá una temperatura máxima de {t_min} ºC, que ocurrirá en {temperaturas.index(t_min)+1} día(s).")
##ver en clase con la profesora para que corrija el manual de respuestas.
# Out:
# Esta semana la temperatura llega a la t_max 1 veces y a la t_min 1 veces
# saturday
# 18
# True
# 18
# La temperatura máxima esta semana será 25 ºC, que ocurrirá en 4 días(s). El día más frío tendrá una temperatura máxima de 18 ºC, que ocurrirá en 6 día(s).

# %% [markdown]
# # Modulo 1 Listas: Nivel Intermedio

# %%
#Duplicar elementos de una lista
#Descripción: Crea una lista de números aleatorios. Duplica cada elemento en la lista. Ejemplo:
# dada la siguiente lista el output esperado es:
#lista = [2, 4, 6, 8]
#[2, 4, 6, 8, 2, 4, 6, 8]

lista=[1,7,11,23,54,90]
lista+=lista
print(lista)
#Combinar dos listas
#Descripción: Crea dos listas nuevas y luego crea una nueva lista que contenga todos los elementos de ambas listas. Ejemplo:
# dadas las siguientes listas el output esperado es:
#lista1 = [1, 2, 3]
#lista2 = [4, 5, 6]
#[1, 2, 3, 4, 5, 6]
lista1=[1,2,3]
lista2=[4,5,6]
lista_join=lista1+lista2
print(lista_join)   
#Calcular la suma de una lista de números
suma_lista_join=sum(lista_join)
print(suma_lista_join)
#Descripción: De la primera lista que creaste, calcula la suma de todos los elementos.
print(sum(lista))
#Encontrar el valor máximo en una lista
print(max(lista))
#Descripción: Encuentra el valor más alto de tu lista.
#Calcular la longitud de una lista
print(len(lista))
#Descripción: Calcula cuántos elementos hay en tu lista.
#Encontrar el índice de un elemento en una lista
lista.index(90)
#Descripción: Elige el número que más te guste de tu lista y encuentra su índice.
#Contar ocurrencias de un elemento en una lista
lista_join.count(6)
#Descripción: Elige un número de tu lista y cuenta cuántas veces aparece.

#Obtener una sublista de una lista
#Descripción: Crea una nueva lista que contenga los elementos desde el índice 2 hasta el índice 5 (sin incluirlo) de tu lista.
sublista=lista[2:5]
print(sublista)

#Obtener el último elemento de una lista
lista[-1]  
#Descripción: Obtén el último elemento de tu lista.

#Obtener el primer elemento de una lista
lista[0]
#Descripción: Obtén el primer elemento de tu lista.

#Obtener una sublista de una lista
#Descripción: Obtén una sublista que contenga los elementos desde el índice 1 hasta el índice 3 (sin incluirlo).
sublista2=lista[1:3]
print(sublista2)
#Reemplazar un elemento en una lista
#Descripción: Reemplaza el segundo elemento con un nuevo valor.
lista[1]=6
print(lista)

#Obtener una lista inversa
#Descripción: Obtén una nueva lista que contenga los elementos en orden inverso.
lista_inversa=lista[::-1]
print(lista_inversa)
lista_inversa2=list(reversed(lista))
print(lista_inversa2)
#Ordenar una lista en orden ascendente
#Descripción: Ordena tu lista en orden ascendente.
lista_inversa2.sort() #sort ordena la lista en orden ascendente a diferencia de sorted que devuelve una nueva lista ordenada sin modificar la original.
print(lista_inversa2)
# Out:
# [1, 7, 11, 23, 54, 90, 1, 7, 11, 23, 54, 90]
# [1, 2, 3, 4, 5, 6]
# 21
# 372
# 90
# 12
# [11, 23, 54]
# [7, 11]
# [1, 6, 11, 23, 54, 90, 1, 7, 11, 23, 54, 90]
# [90, 54, 23, 11, 7, 1, 90, 54, 23, 11, 6, 1]
# [90, 54, 23, 11, 7, 1, 90, 54, 23, 11, 6, 1]
# [1, 1, 6, 7, 11, 11, 23, 23, 54, 54, 90, 90]

# %%
#BONUS

#Obtener elementos pares de una lista
#Descripción: Obtén una nueva lista que contenga solo los elementos en posiciones pares.
lista_pares=lista[::2]
print(lista_pares)
#Obtener una sublista saltando elementos
#Descripción: Obtén una sublista que contenga los elementos de principio a fin, pero saltando de 3 en 3.
lista_saltos_3=lista[::3]
print(lista_saltos_3)
#Teórico. Debereis contestar la pregunta en una celda de markdown.
#Descripción: ¿Qué diferencia existe entre el .sort() y el sorted(). Si no lo sabéis, investigad!
"""sort() ordena la lista  y devuelve None, mientras que sorted() devuelve una nueva lista ordenada sin modificar la original. además, sort() solo funciona con listas, mientras que sorted() puede ordenar cualquier iterable."""
#Agregar elementos a una lista utilizando append y extend
#Descripción: Agrega nuevos elementos a tu lista utilizando tanto append como extend y observa las diferencias en el resultado final. El elemento que deberéis usar para añadir a la lista original tiene que ser una lista.
lista.append([100,200,450])
print(lista)
lista.extend([100,200,450])
print(lista)
#Insertar un elemento en una posición específica
#Descripción: Inserta un nuevo elemento en una posición específica determinada por la usuaria (debereis usar la función input para preguntar a la usuaria en que posición quiere insertar el elemento).
nuevo_elemento = int(input("Indica el nuevo elemento que quieres agregar a la lista: "))
posicion = int(input("Indica la posición donde quieres insertar el elemento: "))
lista.insert(posicion, nuevo_elemento)
print(lista)
#Verificar si un elemento está presente en una lista
#Descripción: Verifica si un elemento específico está presente en ella. Igual que el caso anterior, debereis preguntar a la usuaria que elemento quiere buscar en la lista. El resultado deberá ser True o False.
buscar_elemento = int(input("Indica el elemento que quieres buscar en la lista: "))
print(buscar_elemento in lista)
#Manipulación de una lista utilizando remove(), pop() y clear()
#Descripción: Realiza operaciones de eliminación y limpieza utilizando los métodos remove(), pop() y clear(), y observa cómo afectan a la lista.
lista.remove(6) #elimina el primer elemento que encuentra con el valor indicado
print(lista)
lista.pop(0) #elimina el elemento en la posición indicada y lo devuelve
print(lista)
lista.clear() #elimina todos los elementos de la lista
print(lista)
# Out:
# [1, 11, 54, 1, 11, 54, [100, 200, 450], 200, 29, 100, 450, 100, 450, 100, 450]
# [1, 23, 1, 23, [100, 200, 450], 450, 100, [100, 200, 450], 450, 200]
# [1, 6, 11, 23, 54, 90, 1, 7, 11, 23, 54, 90, [100, 200, 450], 100, 200, 450, 29, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450]]
# [1, 6, 11, 23, 54, 90, 1, 7, 11, 23, 54, 90, [100, 200, 450], 100, 200, 450, 29, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450]
# [22, 1, 6, 11, 23, 54, 90, 1, 7, 11, 23, 54, 90, [100, 200, 450], 100, 200, 450, 29, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450]
# True
# [22, 1, 11, 23, 54, 90, 1, 7, 11, 23, 54, 90, [100, 200, 450], 100, 200, 450, 29, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450, [100, 200, 450], 100, 200, 450]
# ...
