# %% [markdown]
# # Modulo 1 Clases: Nivel Inicial

# %% [markdown]
# Crea una clase llamada Vehiculo que representa un vehículo genérico. Esta clase tiene la capacidad de realizar acciones relacionadas con el vehículo, como encenderlo, apagarlo, acelerar, frenar y detenerlo gradualmente. Cada método en la clase tiene una descripción específica de su función. A continuación, se detallan los aspectos clave de esta clase:
#
# Atributos:
#
# marca: Una cadena que representa la marca del vehículo.
#
# modelo: Una cadena que representa el modelo del vehículo.
#
# año: Un número entero que representa el año de fabricación del vehículo.
#
# velocidad_actual: Un número entero que representa la velocidad actual del vehículo en km/h.
#
# encendido: Un valor booleano que indica si el vehículo está encendido (True) o apagado (False).
#
# Métodos:
#
# __init__(self, marca, modelo, año): El constructor de la clase que inicializa los atributos del vehículo, incluyendo la marca, el modelo, el año, la velocidad actual (inicialmente 0) y el estado del encendido (inicialmente apagado).
#
# informacion(self): Un método que devuelve una cadena de texto con la información básica del vehículo, incluyendo la marca, el modelo y el año.
#
# encender(self): Un método que enciende el vehículo si está apagado y devuelve un mensaje de confirmación. Si el vehículo ya está encendido, devuelve un mensaje indicando que ya está en funcionamiento.
#
# apagar(self): Un método que apaga el vehículo si está encendido, establece la velocidad actual en 0 y devuelve un mensaje de confirmación. Si el vehículo ya está apagado, devuelve un mensaje indicando que ya está apagado.
#
# acelerar(self, velocidad): Un método que aumenta la velocidad actual del vehículo según la cantidad de velocidad proporcionada como argumento. Si el vehículo está encendido, aumenta la velocidad y devuelve un mensaje con la nueva velocidad actual. Si el vehículo está apagado, devuelve un mensaje indicando que no se puede acelerar.
#
# frenar(self, velocidad): Un método que reduce la velocidad actual del vehículo según la cantidad de velocidad proporcionada como argumento. Si el vehículo está encendido, reduce la velocidad y devuelve un mensaje con la nueva velocidad actual. Si el vehículo está apagado, devuelve un mensaje indicando que no se puede frenar.
#
# detener(self): Un método que detiene gradualmente el vehículo reduciendo la velocidad en incrementos de 5 km/h hasta que alcance una velocidad de 0 km/h. Si el vehículo está encendido, detiene el vehículo y devuelve un mensaje de confirmación. Si el vehículo está apagado, devuelve un mensaje indicando que no se puede detener.
#
# Crea la subclase Coche que hereda de la clase base Vehiculo y representa un coche específico. Además de los atributos y métodos heredados, la clase Coche tiene un atributo adicional:
#
# Atributos:
#
# combustible: Una cadena que representa el tipo de combustible que utiliza el coche.
# Métodos:
#
# __init__(self, marca, modelo, año, combustible): Constructor que inicializa los atributos de la clase base y el atributo específico del coche.
# informacion(self): Devuelve una cadena con la información del coche, incluyendo la marca, el modelo, el año y el tipo de combustible.

# %% [markdown]
# Creación de Clase:Vehículo

# %%
class Vehículo:
    def __init__(self,marca,modelo,año,velocidad_actual=0,encendido=False):
        self.marca=marca
        self.modelo=modelo
        self.año=año
        self.velocidad_actual=velocidad_actual
        self.encendido=encendido

    def informacion(self):
        print(f"MARCA:'{self.marca}', MODELO:'{self.modelo}', AÑO: '{self.año}'.\nMe encuentro encendido: {self.encendido}. La velocidad actual es de {self.velocidad_actual} kms/hr.")
    
    def encender(self):
        if not self.encendido and self.velocidad_actual == 0: 
            self.encendido = True
            self.velocidad_actual = 0
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, se encuentra ahora encendido a una velocidad de {self.velocidad_actual} km/hr.")
        
        else:
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, ya se encuentra encendido a una velocidad de {self.velocidad_actual} kms/hr.")

    def apagar(self):
        if self.encendido and self.velocidad_actual == 0:
            self.encendido = False
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, se encuentra ahora apagado.") 
        
        elif self.encendido and self.velocidad_actual != 0:
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, se encuentra circulando a una velocidad de {self.velocidad_actual} km/hr.\nDeten el vehículo antes de apagarlo.") #PARA CONTROL VAR:VELOCIDAD

        else:
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, estaba apagado.")
    
    def acelerar(self,velocidad):
        if velocidad >0 and self.encendido and self.velocidad_actual < 250: ##incluye limite maximo del auto =250 km/hr.
            self.velocidad_actual+=velocidad
            if self.velocidad_actual >=250:
                self.velocidad_actual = 250
                print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, ha alcanzado la velocidad máxima de 250 km/hr.")
            elif 250 > self.velocidad_actual >= 150:
                print(f"PRECAUCIÓN: La velocidad actual del vehículo {self.marca}, {self.modelo}, año {self.año}, es de {self.velocidad_actual}.")
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, se encuentra ahora circulando a {self.velocidad_actual} km/hr.")
        elif velocidad >0 and self.encendido and self.velocidad_actual == 250:
                print(f"La velocidad actual del vehículo {self.marca}, {self.modelo}, año {self.año},es la máxima: {self.velocidad_actual} km/hr.\nNo se puede acelerar más.")
               
        elif velocidad >0 and not self.encendido: #ver si es posible o no y eliminar.
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, se encuentra actualmente apagado, primero debes encenderlo.")
        else: 
            print("No puedes ingresar una velocidad para acelerar menor a 0(cero). Debes ingresar una velocidad positiva.\nSi quieres reducir la velocidad, entonces intenta frenar.")    

    def frenar(self,velocidad):
        if not self.encendido:
            print(f"El vehiculo {self.marca}, {self.modelo}, año {self.año}, se encuentra detenido. No se puede frenar.")
        else:
            if self.velocidad_actual > velocidad > 0:
                self.velocidad_actual-=velocidad
                print(f"Se redujo la velocidad del vehículo {self.marca}, {self.modelo}, año {self.año} y actualmente la velocidad es de: {self.velocidad_actual} km/hr.")
                if self.velocidad_actual < 0:
                    self.velocidad_actual = 0
                    print(f"La velocidad actual del vehículo {self.marca}, {self.modelo}, año {self.año} es {self.velocidad_actual} km/hr.\nPuedes detener el vehículo y apagarlo, o acelerar.")
    
    def detenerse(self):
        if not self.encendido:
            print(f"El vehiculo {self.marca}, {self.modelo}, año {self.año}, ya se encuentra detenido y apagado.")
            return
        elif self.velocidad_actual == 0:
            print(f"El vehículo {self.marca}, {self.modelo}, año {self.año}, ya se encontraba detenido.")
            return
        while self.velocidad_actual >0:
            self.velocidad_actual -= 5
            if self.velocidad_actual < 0:
                self.velocidad_actual = 0
            print(f"Frenando... : {self.velocidad_actual}km/hr.")
        print(f"El vehiculo {self.marca}, {self.modelo}, año {self.año}, se ha detenido.")

# %%
fiat_1=Vehículo("fiat","1",2010)

# %%
fiat_1.informacion()
# Out:
# MARCA:'fiat', MODELO:'1', AÑO: '2010'.
# Me encuentro encendido: False. La velocidad actual es de 0 kms/hr.

# %%
fiat_1.apagar()
# Out:
# El vehículo fiat, 1, año 2010, estaba apagado.

# %%
fiat_1.acelerar(100)
# Out:
# El vehículo fiat, 1, año 2010, se encuentra actualmente apagado, primero debes encenderlo.

# %%
fiat_1.encender()
# Out:
# El vehículo fiat, 1, año 2010, se encuentra ahora encendido a una velocidad de 0 km/hr.

# %%
fiat_1.encender()
# Out:
# El vehículo fiat, 1, año 2010, ya se encuentra encendido a una velocidad de 0 kms/hr.

# %%
fiat_1.acelerar(140)
# Out:
# El vehículo fiat, 1, año 2010, se encuentra ahora circulando a 140 km/hr.

# %%
fiat_1.acelerar(50)
# Out:
# PRECAUCIÓN: La velocidad actual del vehículo fiat, 1, año 2010, es de 190.
# El vehículo fiat, 1, año 2010, se encuentra ahora circulando a 190 km/hr.

# %%
fiat_1.acelerar(60)
# Out:
# El vehículo fiat, 1, año 2010, ha alcanzado la velocidad máxima de 250 km/hr.
# El vehículo fiat, 1, año 2010, se encuentra ahora circulando a 250 km/hr.

# %%
fiat_1.acelerar(50)
# Out:
# La velocidad actual del vehículo fiat, 1, año 2010,es la máxima: 250 km/hr.
# No se puede acelerar más.

# %%
fiat_1.acelerar(-25)
# Out:
# No puedes ingresar una velocidad para acelerar menor a 0(cero). Debes ingresar una velocidad positiva.
# Si quieres reducir la velocidad, entonces intenta frenar.

# %%
fiat_1.frenar(60)
# Out:
# Se redujo la velocidad del vehículo fiat, 1, año 2010 y actualmente la velocidad es de: 190 km/hr.

# %%
fiat_1.detenerse()
# Out:
# Frenando... : 185km/hr.
# Frenando... : 180km/hr.
# Frenando... : 175km/hr.
# Frenando... : 170km/hr.
# Frenando... : 165km/hr.
# Frenando... : 160km/hr.
# Frenando... : 155km/hr.
# Frenando... : 150km/hr.
# Frenando... : 145km/hr.
# Frenando... : 140km/hr.
# Frenando... : 135km/hr.
# Frenando... : 130km/hr.
# Frenando... : 125km/hr.
# Frenando... : 120km/hr.
# Frenando... : 115km/hr.
# Frenando... : 110km/hr.
# Frenando... : 105km/hr.
# Frenando... : 100km/hr.
# Frenando... : 95km/hr.
# Frenando... : 90km/hr.
# Frenando... : 85km/hr.
# Frenando... : 80km/hr.
# Frenando... : 75km/hr.
# Frenando... : 70km/hr.
# Frenando... : 65km/hr.
# Frenando... : 60km/hr.
# Frenando... : 55km/hr.
# Frenando... : 50km/hr.
# Frenando... : 45km/hr.
# Frenando... : 40km/hr.
# Frenando... : 35km/hr.
# Frenando... : 30km/hr.
# Frenando... : 25km/hr.
# Frenando... : 20km/hr.
# Frenando... : 15km/hr.
# Frenando... : 10km/hr.
# Frenando... : 5km/hr.
# Frenando... : 0km/hr.
# El vehiculo fiat, 1, año 2010, se ha detenido.

# %%
fiat_1.apagar()
# Out:
# El vehículo fiat, 1, año 2010, se encuentra ahora apagado.

# %%
fiat_1.acelerar(15)
# Out:
# El vehículo fiat, 1, año 2010, se encuentra actualmente apagado, primero debes encenderlo.

# %%
fiat_1.encender()
# Out:
# El vehículo fiat, 1, año 2010, se encuentra ahora encendido a una velocidad de 0 km/hr.

# %%
fiat_1.acelerar(25)
# Out:
# El vehículo fiat, 1, año 2010, se encuentra ahora circulando a 25 km/hr.

# %%
fiat_1.apagar()
# Out:
# El vehículo fiat, 1, año 2010, se encuentra circulando a una velocidad de 25 km/hr.
# Deten el vehículo antes de apagarlo.

# %%
fiat_1.detenerse()
# Out:
# Frenando... : 20km/hr.
# Frenando... : 15km/hr.
# Frenando... : 10km/hr.
# Frenando... : 5km/hr.
# Frenando... : 0km/hr.
# El vehiculo fiat, 1, año 2010, se ha detenido.

# %%
fiat_1.apagar()
# Out:
# El vehículo fiat, 1, año 2010, se encuentra ahora apagado.

# %% [markdown]
# Creación de SubClase: Coche

# %%
class Coche(Vehículo):
    def __init__(self,modelo,marca,año,combustible,velocidad_actual=0,encendido=False):
        super().__init__(modelo,marca,año,velocidad_actual=0,encendido=False)
        self.combustible=combustible

# %%
auto=Coche("Peugeot","2008","2020","nafta")

# %%
print(help(Coche))
# Out:
# Help on class Coche in module __main__:
#
# class Coche(Vehículo)
#  |  Coche(modelo, marca, año, combustible, velocidad_actual=0, encendido=False)
#  |
#  |  Method resolution order:
#  |      Coche
#  |      Vehículo
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(
#  |      self,
#  |      modelo,
#  |      marca,
#  |      año,
#  |      combustible,
#  |      velocidad_actual=0,
#  |      encendido=False
#  |  )
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Vehículo:
#  |
#  |  acelerar(self, velocidad)
#  |
#  |  apagar(self)
#  |
#  |  detenerse(self)
#  |
#  |  encender(self)
#  |
#  |  frenar(self, velocidad)
#  |
#  |  informacion(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Vehículo:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#
# None

# %%
auto.informacion()
# Out:
# MARCA:'Peugeot', MODELO:'2008', AÑO: '2020'.
# Me encuentro encendido: False. La velocidad actual es de 0 kms/hr.
